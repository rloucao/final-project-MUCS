# %%
import requests
import pandas as pd
import json
import warnings

import os

FIRST_PAGE = 1
LAST_PAGE = 13

# %%
# load .csv files to pandas dataframe
CUR_DIR = os.getcwd()
DB_LIST_PATH = os.path.join(CUR_DIR, 'plant_list.csv')
DB_LIST_ENTRIES = ['id', 'common_name', 'scientific_name', 'other_name', 'family', 'hybrid', 'authority', 'subspecies', 'cultivar', 'variety', 'species_epithet', 'genus', 'regular_url', 'medium_url', 'small_url', 'thumbnail']

# check if file exists and load it, else create a new dataframe
if os.path.exists(DB_LIST_PATH):
    plant_list_df = pd.read_csv(DB_LIST_PATH)
    print(plant_list_df.head())
    current_page = int((plant_list_df['id'].max() / 30) + 1)
    if current_page > LAST_PAGE:
        print("WARNING: Current page exceeds the last page. Plant list should be complete!")
    print(f"Next page to scrape [current page]: {current_page}")
else:
    plant_list_df = pd.DataFrame(columns=DB_LIST_ENTRIES)
    print("No plant list found. Creating a new one.")
    current_page = FIRST_PAGE
# Out:
# No plant list found. Creating a new one.

# %%
PERENUAL_API_URL = "https://perenual.com/api/v2/species-list"
PERENUAL_API_KEY = "sk-CIqR67f7e96325b299717"

# %%
wait_time = 5 # minutes

while current_page < LAST_PAGE:
    url = f"{PERENUAL_API_URL}?key={PERENUAL_API_KEY}&page={current_page}&indoor=1"
    print(f"requesting {url}")

    payload = {}
    headers = {}
    
    response = requests.request("GET", url, headers=headers, data=payload)

    if response.status_code == 200:
        # get the data
        data = response.json()
        data = data['data']

        # iterate over the data and add it to the dataframe
        for entry in data:
            # check if the entry already exists in the dataframe
            if entry['id'] not in plant_list_df['id'].values:
                # create df row
                row = pd.DataFrame([{
                    'id': entry['id'],
                    'common_name': entry.get('common_name', "null"),
                    'scientific_name': entry.get('scientific_name', "null"),
                    'other_name': entry.get('other_name', "null"),
                    'family': entry.get('family', "null"),
                    'hybrid': entry.get('hybrid', "null"),
                    'authority': entry.get('authority', "null"),
                    'subspecies': entry.get('subspecies', "null"),
                    'cultivar': entry.get('cultivar', "null"),
                    'variety': entry.get('variety', "null"),
                    'species_epithet': entry.get('species_epithet', "null"),
                    'genus': entry.get('genus', "null"),
                    'regular_url': entry['default_image']['regular_url'] if 'default_image' in entry and entry['default_image'] is not None and 'regular_url' in entry['default_image'] else 'null',
                    'medium_url': entry['default_image']['medium_url'] if 'default_image' in entry and entry['default_image'] is not None and 'medium_url' in entry['default_image'] else 'null',
                    'small_url': entry['default_image']['small_url'] if 'default_image' in entry and entry['default_image'] is not None and 'small_url' in entry['default_image'] else 'null',
                    'thumbnail': entry['default_image']['thumbnail'] if 'default_image' in entry and entry['default_image'] is not None and 'thumbnail' in entry['default_image'] else 'null'
                }])
                with warnings.catch_warnings():
                    warnings.simplefilter("ignore")
                    plant_list_df = pd.concat([plant_list_df, row], ignore_index=True)
                print(f"\tadded {entry['id']}: {entry['common_name']}")
            else:
                print(f"\t{entry['id']}: {entry['common_name']} already exists in the dataframe. Skipping...")

        current_page += 1
        wait_time = 5

    elif response.status_code == 429:
        print("Max API requests reached. Try again tomorrow.")
        print(f"Set current_page manually to {current_page} to continue scraping.")
        break
    else:
        print(f"Error: {response.status_code}")
        print(f"Wait for {wait_time} minutes...")
        
        time.sleep(int(wait_time) * 60) # wait for the specified time
        if wait_time < 60:
            wait_time += 5 

print("Saving plant list to CSV...")
plant_list_df.to_csv(DB_LIST_PATH, index=False)
print("Plant list saved.")
# Out:
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=1&indoor=1
# 	added 425: flowering-maple
# 	added 426: flowering-maple
# 	added 427: flowering-maple
# 	added 428: flowering-maple
# 	added 434: Jacob's coat
# 	added 502: hot water plant
# 	added 540: desert rose
# 	added 543: maidenhair fern
# 	added 546: delta maidenhair fern
# 	added 549: urn plant
# 	added 551: stalked aeonium
# 	added 552: lipstick plant
# 	added 625: Philippine evergreen
# 	added 626: Chinese evegreen
# 	added 627: Chinese evergreen
# 	added 628: Chinese evergreen
# 	added 667: onion
# 	added 710: elephant's ear
# 	added 711: Amazonian elephant's ear
# 	added 712: elephant's ear
# 	added 713: elephant's ear
# 	added 714: elephant's ear
# 	added 715: giant elephant's ear
# 	added 716: elephant's ear
# 	added 717: elephant's ear
# 	added 718: elephant's ear
# 	added 721: aloe
# 	added 727: aloe
# 	added 728: aloe
# 	added 747: Joseph's coat
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=2&indoor=1
# 	added 748: Joseph's coat
# 	added 855: anthurium
# 	added 856: anthurium
# 	added 861: zebra plant
# 	added 1001: trailing snapdragon
# 	added 1023: Sprenger's asparagus fern
# 	added 1024: asparagus fern
# 	added 1025: asparagus fern
# 	added 1031: asparagus fern
# 	added 1036: cast-iron plant
# 	added 1038: bird's nest fern
# 	added 1130: Japanese painted fern
# 	added 1133: Japanese painted fern
# 	added 1147: spotted laurel
# 	added 1149: spotted laurel
# 	added 1150: spotted laurel
# 	added 1192: ponytail palm
# 	added 1194: begonia
# 	added 1195: begonia
# 	added 1196: begonia
# 	added 1197: begonia
# 	added 1198: begonia
# 	added 1199: begonia
# 	added 1200: begonia
# 	added 1201: begonia
# 	added 1202: begonia
# 	added 1203: hybrid tuberous begonia
# 	added 1208: begonia
# 	added 1209: begonia
# 	added 1210: begonia
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=3&indoor=1
# 	added 1211: begonia
# 	added 1212: iron cross begonia
# 	added 1213: begonia
# 	added 1214: rex begonia
# 	added 1215: rex begonia
# 	added 1216: begonia
# 	added 1217: begonia
# 	added 1218: begonia
# 	added 1219: wax begonia
# 	added 1220: angelwing begonia
# 	added 1221: begonia
# 	added 1222: angelwing begonia
# 	added 1223: hybrid tuberous begonia
# 	added 1224: hybrid tuberous begonia
# 	added 1225: begonia
# 	added 1226: hybrid tuberous begonia
# 	added 1272: jewel plant
# 	added 1416: boxwood
# 	added 1457: angel wings
# 	added 1468: orchid
# 	added 1469: rattlesnake plant
# 	added 1470: peacock plant
# 	added 1471: zebra plant
# 	added 1597: ornamental pepper
# 	added 1598: ornamental pepper
# 	added 1601: ornamental pepper
# 	added 1603: ornamental pepper
# 	added 1716: orchid
# 	added 1820: parlor palm
# 	added 1821: chamaedorea
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=4&indoor=1
# 	added 1822: bamboo palm
# 	added 1845: St. Bernard's lily
# 	added 1846: spider plant
# 	added 1847: spider plant
# 	added 1848: spider plant
# 	added 1855: chrysanthemum
# 	added 1864: chrysanthemum
# 	added 1868: chrysanthemum
# 	added 1870: chrysanthemum
# 	added 1871: chrysanthemum
# 	added 1873: chrysanthemum
# 	added 1891: meyer lemon
# 	added 1971: bleeding heart
# 	added 1993: Natal lily
# 	added 1999: croton
# 	added 2000: croton
# 	added 2030: columnea
# 	added 2193: jade plant
# 	added 2242: firecracker flower
# 	added 2244: cryptanthus
# 	added 2263: cuphea
# 	added 2272: Sago palm
# 	added 2274: Persian violet
# 	added 2275: cyclamen
# 	added 2277: cymbalaria
# 	added 2279: orchid
# 	added 2287: umbrella plant
# 	added 2288: umbrella plant
# 	added 2289: umbrella plant
# 	added 2290: umbrella plant
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=5&indoor=1
# 	added 2294: Japanese holly fern
# 	added 2295: Japanese holly fern
# 	added 2322: rabbit's foot fern
# 	added 2323: rabbit's foot fern
# 	added 2354: orchid
# 	added 2468: dumb cane
# 	added 2498: Venus fly trap
# 	added 2499: Venus fly trap
# 	added 2500: Venus fly trap
# 	added 2501: Venus fly trap
# 	added 2528: fragrant dracaena
# 	added 2529: striped dracaena
# 	added 2530: striped dracaena
# 	added 2531: dragontree
# 	added 2532: song of India
# 	added 2533: dracaena
# 	added 2568: bamboo palm
# 	added 2773: golden pothos
# 	added 2774: pothos
# 	added 2775: flame violet
# 	added 2829: Amazon lily
# 	added 2885: christplant
# 	added 2891: poinsettia
# 	added 2915: Persian violet
# 	added 2954: weeping fig
# 	added 2955: weeping fig
# 	added 2956: fig
# 	added 2957: fig
# 	added 2958: fig
# 	added 2959: fig
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=6&indoor=1
# 	added 2961: Indian rubberplant
# 	added 2962: India rubber plant
# 	added 2963: fiddle-leaf fig
# 	added 2965: climbing fig
# 	added 2976: Nerve Plant
# 	added 3087: gardenia
# 	added 3089: gardenia
# 	added 3090: gardenia
# 	added 3236: goeppertia
# 	added 3256: scarlet star
# 	added 3259: velvet plant
# 	added 3347: Persian ivy
# 	added 3349: English ivy
# 	added 3350: English ivy
# 	added 3351: English ivy
# 	added 3352: English ivy
# 	added 3353: English ivy
# 	added 3354: English ivy
# 	added 3355: Nepal ivy
# 	added 3637: red ivy
# 	added 3828: amaryllis
# 	added 3971: wax plant
# 	added 3972: miniature wax plant
# 	added 3986: common hyacinth
# 	added 3988: common hyacinth
# 	added 4122: pennywort
# 	added 4181: polka dot plant
# 	added 4182: polka dot plant
# 	added 4183: polka dot plant
# 	added 4280: busy lizzy
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=7&indoor=1
# 	added 4304: sweet potato vine
# 	added 4349: iris
# 	added 4554: shrimp plant
# 	added 4557: velvet leaf kalanchoe
# 	added 4558: kalanchoe
# 	added 4559: kalanchoe
# 	added 4722: lavender
# 	added 4727: Cooper’s African hyacinth
# 	added 4901: orienpet lily
# 	added 4947: lobelia
# 	added 4956: lobelia
# 	added 5007: jewel orchid
# 	added 5159: prayer plant
# 	added 5180: showy medinilla
# 	added 5203: marvel of Peru
# 	added 5257: Swiss cheese plant
# 	added 5258: variegated Swiss cheese plant
# 	added 5269: centipede plant
# 	added 5443: blushing bromeliad
# 	added 5444: catmint
# 	added 5445: catnip
# 	added 5446: catmint
# 	added 5449: nepeta
# 	added 5462: nepeta
# 	added 5465: Boston fern
# 	added 5466: Boston fern
# 	added 5467: Boston fern
# 	added 5497: sweet basil
# 	added 5498: basil
# 	added 5520: orchid
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=8&indoor=1
# 	added 5564: fragrant olive
# 	added 5588: Guiana chestnut
# 	added 5589: water chestnut
# 	added 5706: Venus' slipper
# 	added 5726: passion flower
# 	added 5736: regal geranium
# 	added 5737: zonal geranium
# 	added 5738: ivyleaf geranium
# 	added 5739: scented-leaved geranium
# 	added 5740: button fern
# 	added 5741: trailing watermelon begonia
# 	added 5806: watermelon peperomia
# 	added 5807: emerald ripple pepper
# 	added 5808: baby rubber plant
# 	added 5810: florist's cineraria
# 	added 5836: orchid
# 	added 5837: moth orchid
# 	added 5868: horsehead philodendron
# 	added 5869: vilevine
# 	added 5870: philodendron
# 	added 5871: philodendron
# 	added 5950: orchid
# 	added 6068: aluminum plant
# 	added 6069: friendship plant
# 	added 6070: artillery plant
# 	added 6071: pilea
# 	added 6178: elkhorn fern
# 	added 6197: Swedish ivy
# 	added 6199: coleus
# 	added 6200: coleus
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=9&indoor=1
# 	added 6201: coleus
# 	added 6202: Swedish ivy
# 	added 6203: Swedish ivy
# 	added 6204: coleus
# 	added 6205: coleus
# 	added 6206: Swedish ivy
# 	added 6207: coleus
# 	added 6208: dwarf fern-leaf bamboo
# 	added 6210: false aralia
# 	added 6252: fern-leaf aralia
# 	added 6253: Ming aralia
# 	added 6311: primula
# 	added 6317: primula
# 	added 6318: primula
# 	added 6405: cretan brake
# 	added 6535: Asian bell tree
# 	added 6554: lady palm
# 	added 6809: miniature rose
# 	added 6913: miniature rose
# 	added 6920: miniature rose
# 	added 7030: African violet
# 	added 7163: bowstring hemp
# 	added 7164: blue sansevieria
# 	added 7165: mother-in-law's tongue
# 	added 7166: mother-in-law's tongue
# 	added 7167: Mason's Congo sansevieria
# 	added 7168: snake plant
# 	added 7169: mother-in-law's tongue
# 	added 7170: bowstring hemp
# 	added 7171: viper's bowstring hemp
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=10&indoor=1
# 	added 7172: mother-in-law's tongue
# 	added 7173: mother-in-law's tongue
# 	added 7174: mother-in-law's tongue
# 	added 7175: mother-in-law's tongue
# 	added 7176: mother-in-law's tongue
# 	added 7177: mother-in-law's tongue
# 	added 7186: sweet box
# 	added 7187: sweet box
# 	added 7188: sweet box
# 	added 7189: fragrant sweet box
# 	added 7244: octopus tree
# 	added 7245: umbrella plant
# 	added 7265: Christmas cactus
# 	added 7266: Christmas cactus
# 	added 7276: satin pothos
# 	added 7345: string of pearls
# 	added 7352: snowrose
# 	added 7353: snowrose
# 	added 7354: snowrose
# 	added 7384: gloxinia
# 	added 7405: eggplant
# 	added 7409: potato
# 	added 7410: baby's tears
# 	added 7463: peace lily
# 	added 7569: Cape primrose
# 	added 7571: stromanthe
# 	added 7572: stromanthe
# 	added 7639: American evergreen
# 	added 7640: arrowhead plant
# 	added 7681: batflower
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=11&indoor=1
# 	added 7743: tropical almond
# 	added 7858: foam flower
# 	added 7864: foam flower
# 	added 7866: foam flower
# 	added 7873: foam flower
# 	added 7890: wishbone flower
# 	added 7901: spiderwort
# 	added 7902: spiderwort
# 	added 7903: spiderwort
# 	added 7904: spiderwort
# 	added 7905: spiderwort
# 	added 7906: spiderwort
# 	added 7907: spiderwort
# 	added 7908: spiderwort
# 	added 7910: spiderwort
# 	added 7911: small-leaf spiderwort
# 	added 7912: spiderwort
# 	added 7913: spiderwort
# 	added 7914: spiderwort
# 	added 7915: spiderwort
# 	added 7917: spider lily
# 	added 7918: boat lily
# 	added 7919: Moses-in-a-basket
# 	added 7920: zigzag spiderwort
# 	added 7921: spider lily
# 	added 7923: inch plant
# 	added 8004: tulip
# 	added 8132: speedwell
# 	added 8314: vriesea
# 	added 8377: Spineless yucca
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=12&indoor=1
# 	added 8385: cardboard palm
# 	added 8386: ZZ plant
# 	added 8387: ZZ plant
# 	added 8422: orchid
# 	added 8480: Chinese lantern
# 	added 8485: Chinese evergreen
# 	added 8487: hybrid ornamental onion
# 	added 8494: anthurium
# 	added 8509: calathea
# 	added 8512: ornamental pepper
# 	added 8520: string of hearts
# 	added 8538: earth star
# 	added 8543: cyclamen
# 	added 8549: ribbon plant
# 	added 8550: gold-dust dracaena
# 	added 8565: crown of thorns
# 	added 8588: geranium
# 	added 8596: creeping Charlie
# 	added 8601: Easter cactus
# 	added 8603: variegated Persian ivy
# 	added 8610: coral bells
# 	added 8613: amaryllis
# 	added 8622: sweet potato vine
# 	added 8625: jasmine
# 	added 8652: red-veined prayer plant
# 	added 8653: prayer plant
# 	added 8677: false shamrock
# 	added 8679: passion flower
# 	added 8680: zonal geranium
# 	added 8681: pelargonium
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=13&indoor=1
# 	added 8682: silver-leaf peperomia
# 	added 8683: spoon leaf peperomia
# 	added 8685: hybrid philodendron
# 	added 8691: artillery plant
# 	added 8692: creeping Charlie
# 	added 8699: coleus
# 	added 8700: Swedish ivy
# 	added 8704: Balfour aralia
# 	added 8709: primula
# 	added 8717: table fern
# 	added 8722: majesty palm
# 	added 8743: false aralia
# 	added 8755: string-of-pearls
# 	added 8763: peace lily
# 	added 8765: cape primrose
# 	added 8766: bacopa
# 	added 8778: piggyback plant
# 	added 8791: bromeliad
# 	added 8794: yucca
# 	added 8798: calamondin orange
# 	added 8836: Green Mountain Maidenhair Fern
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=14&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=15&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=16&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=17&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=18&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=19&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=20&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=21&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=22&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=23&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=24&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=25&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=26&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=27&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=28&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=29&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=30&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=31&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=32&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=33&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=34&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=35&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=36&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=37&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=38&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=39&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=40&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=41&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=42&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=43&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=44&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=45&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=46&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=47&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=48&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=49&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=50&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=51&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=52&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=53&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=54&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=55&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=56&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=57&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=58&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=59&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=60&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=61&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=62&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=63&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=64&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=65&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=66&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=67&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=68&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=69&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=70&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=71&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=72&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=73&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=74&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=75&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=76&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=77&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=78&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=79&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=80&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=81&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=82&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=83&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=84&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=85&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=86&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=87&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=88&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=89&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=90&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=91&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=92&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=93&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=94&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=95&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=96&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=97&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=98&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=99&indoor=1
# requesting https://perenual.com/api/v2/species-list?key=sk-CIqR67f7e96325b299717&page=100&indoor=1
# Max API requests reached. Try again tomorrow.
# Set current_page manually to 100 to continue scraping.
# Saving plant list to CSV...
# Plant list saved.
